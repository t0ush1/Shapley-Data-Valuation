# %%
import matplotlib.pyplot as plt

# def mse_loss(list1, list2):
#     if len(list1) != len(list2):
#         raise ValueError("Both lists must have the same length.")

#     mse = sum((x - y) ** 2 for x, y in zip(list1, list2)) / len(list1)
#     return mse

def mse_loss(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("Both lists must have the same length.")

    mse = sum((x - y) ** 2 for x, y in zip(list1, list2)) / len(list1)
    
    if not list2 or all(value == 0 for value in list2):
        raise ValueError("The second list cannot be all zeros or empty for MSE-based error ratio calculation.")

    avg_square_reference = sum(y ** 2 for y in list2) / len(list2)

    return mse / avg_square_reference

# Example usage
# vector1 = [1, 2, 3, 4]
# vector2 = [2, 3, 4, 5]

# ratio = mse_based_error_ratio(vector1, vector2)
# print("MSE-Based Error Ratio:", ratio)

def l2_loss(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("Both lists must have the same length.")

    if not list2 or all(value == 0 for value in list2):
        raise ValueError("The second list cannot be all zeros or empty for L2 norm-based error ratio calculation.")

    l2_norm_difference = sum((x - y) ** 2 for x, y in zip(list1, list2)) ** 0.5
    l2_norm_reference = sum(y ** 2 for y in list2) ** 0.5

    return l2_norm_difference / l2_norm_reference

DEF = [0.09234986014900703, 0.09269516307801486, 0.09176603161271604, 0.0933278885684787, 0.09329225783428505, 0.09289330010494548, 0.0941301189067345, 0.09258023860553895, 0.09325150105333534, 0.09406236048846964] 
KG = {key: [] for key in range(1, 10)}
TM = {key: [] for key in range(1, 10)}
KG[1] = [0.09105358384549618, 0.09082582257688046, 0.0904560174793005, 0.09168299101293087, 0.0916536059230566, 0.09131563566625119, 0.09072541259229183, 0.0900837566703558, 0.09108052514493466, 0.09186667464673519]
TM[1]=257.19810998400135
KG[2] = [0.09217579758001698, 0.0920655912409226, 0.0915031273745828, 0.0929001728279723, 0.09291024535066551, 0.0924990759541591, 0.0921608335028092, 0.09130093914767107, 0.09231621287763118, 0.0932288950930039]
TM[2]=1488.6537403350121
KG[3] = [0.09242254061003527, 0.09239138459993732, 0.09173422335750528, 0.09319480835563604, 0.0931969215058618, 0.09276615973148081, 0.09274221257203155, 0.09175217826333312, 0.09272962754799263, 0.09363734320633942]
TM[3]=5134.971775568058
KG[4] = [0.09246560333385352, 0.09246803447012863, 0.09176737297740242, 0.09327011697940404, 0.0932586729822178, 0.09282138031271718, 0.09306327235249298, 0.09197166051774741, 0.09288741679536924, 0.09379740658378792]
TM[4]=12311.541705292035
KG[5] = [0.09247574946355253, 0.09249858932480923, 0.0917667896560733, 0.09330034107561141, 0.09328570964908792, 0.09283556900918487, 0.09330090883350564, 0.09213040192567161, 0.09298232739998238, 0.0938814325287702]
TM[5]=22068.277091114964
KG[6] = [0.0924811923610313, 0.09252865896929828, 0.09176284439625246, 0.09331915627514548, 0.09331340759637813, 0.09284153642753765, 0.09349399628265508, 0.09225816135959958, 0.09307204885260463, 0.09393846111756468]
TM[6]=31232.122303198965
KG[7] = [0.09247218311897351, 0.09254883450293358, 0.09175861679490598, 0.09331347070161293, 0.09331620631828198, 0.09284010776096872, 0.09365493428730774, 0.09234737666944655, 0.09313986453390324, 0.09397201888736277]
TM[7]=37063.39001997995
KG[8] = [0.09241381394602954, 0.09253216689186441, 0.0917222215365323, 0.09326040750103318, 0.09326151110941458, 0.09280568525076864, 0.09377364604364313, 0.09238077894681024, 0.09316197487688269, 0.09397147466384229]
TM[8]=39479.774506596965
KG[9] = [0.09236455865440865, 0.09258985359162569, 0.09170480572160275, 0.0932519701324283, 0.09327756528934791, 0.09280758862575847, 0.09391949993395618, 0.09246023657421265, 0.0932294592556974, 0.09404276844173196]
TM[9]=40069.76447221999
KG[10] = [0.09234986014900703, 0.09269516307801486, 0.09176603161271604, 0.0933278885684787, 0.09329225783428505, 0.09289330010494548, 0.0941301189067345, 0.09258023860553895, 0.09325150105333534, 0.09406236048846964]
TM[10]=40134.94407950698
CC = [0.05673194486601172, 0.05756955524601268, 0.05817932698538269, 0.057842532388083595, 0.057752128588681485, 0.06096063955646028, 0.0647302408606158, 0.061339192845303606, 0.05759211477995331, 0.05836895883970318]
L2 = [l2_loss(KG[i], DEF) for i in range(1,11)]


TMC = [0.09125685157875221, 0.03193164952099323, 0.0907980686674515, 0.06359390392899514, 0.09432062767446041, 0.06197508548696837, 0.12373628765344621, 0.12266441136598591, 0.09427736463646096, 0.15580671864251297]  
# [0.11039919331669809, 0.057824741974472994, 0.05401793040335175, 0.09412862084805965, 0.09405074618756767, 0.07518808335065841, 0.12965174205601213, 0.10921482637524606, 0.09353987120091917, 0.11232807710766787]
print("KG-L2:", L2)
print("KG-Time:", TM)
cc_l2 = l2_loss(CC, DEF)

print("CC-L2:", cc_l2, "Time=11774")
tmc_l2= l2_loss(TMC, DEF)
print("MC-L2:", tmc_l2, "Time=11500")

MSE = [mse_loss(KG[i], DEF) for i in range(1,10)]
print(MSE)
# Out:
# KG-L2: [0.022061484078930726, 0.009652109442866885, 0.006086359070776312, 0.0045422584292317, 0.003489089425862027, 0.002641832983866715, 0.0019839093266159394, 0.0016261121402459014, 0.0010083492939605078, 0.0]
# KG-Time: {1: 257.19810998400135, 2: 1488.6537403350121, 3: 5134.971775568058, 4: 12311.541705292035, 5: 22068.277091114964, 6: 31232.122303198965, 7: 37063.39001997995, 8: 39479.774506596965, 9: 40069.76447221999, 10: 40134.94407950698}
# CC-L2: 0.3654201012265488 Time=11774
# MC-L2: 0.3585900034187772 Time=11500
# [0.00048670907976491385, 9.316321669708005e-05, 3.70437667384211e-05, 2.0632111637926427e-05, 1.2173745021662207e-05, 6.97928151464611e-06, 3.935896216233709e-06, 2.6442406926551053e-06, 1.0167682986306545e-06]

# %%
T = [v for k,v in TM.items()]
L = [100*x for x in L2]
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FuncFormatter
# Set the font properties (make sure the path is correct)
# tnr_font = FontProperties(fname='/usr/share/fonts/truetype/msttcorefonts/times.ttf', size=45)
tnr_font = FontProperties(family="Times New Roman", size=45)
# tnr_font_30 = FontProperties(fname='/usr/share/fonts/truetype/msttcorefonts/times.ttf', size=45)

def to_percent(y, position):
    """ Convert the y-axis values to percentages. """
    return f"{y:.1f}%"

def plot_for_publication(L2, TM):
    k = range(1, len(L2)+1)  # Indices for the x-axis

    # Set the font properties for Times New Roman
    # tnr_font = FontProperties(family='Times New Roman', size=12)

    fig, ax1 = plt.subplots(figsize=(18, 10))

    # Plot L2 on the primary y-axis
    # color_L2 = 'tab:darkblue'
    ax1.plot(k, L2, color='b', marker='>', linewidth=5, markersize=20, label='Error (by $L_{2}$-Norm)')
    ax1.set_xlabel('$k$', fontproperties=tnr_font)
    # ax1.set_ylabel('Approximation Error (by $L_{2}$)', fontproperties=tnr_font)
    ax1.set_ylabel('Approximation Error [%]', fontproperties=tnr_font)

    # Set font for x-axis and y-axis tick labels
    for label in ax1.get_xticklabels():
        label.set_fontproperties(tnr_font)
    for label in ax1.get_yticklabels():
        label.set_fontproperties(tnr_font)

    # Create a second y-axis for TM with logarithmic scale
    ax2 = ax1.twinx()
    # color_TM = 'tab:blue'
    ax2.plot(k, TM, color='r', marker='o', linewidth=5, markersize=20, label='Running Time')
    ax2.set_ylabel('Running Time (Secs)', fontproperties=tnr_font)
    ax2.set_yscale('log')

    # Adding more grid lines
    ax1.set_xticks(range(min(k), max(k)+1))  # Adjust the range and step as needed
    ax1.set_yticks([i/10 for i in range(int(min(L2)*10), int(max(L2)*10)+1, 5)])  # Adjust for L2
    ax1.yaxis.set_major_formatter(FuncFormatter(to_percent))
    # ax2.set_yticks([10**i for i in range(int(min(TM)), int(max(TM))+1)])  # Adjust for TM

    # Set font for y-axis tick labels of the second axis
    for label in ax2.get_yticklabels():
        label.set_fontproperties(tnr_font)

    # Adding legends
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='center right', prop=tnr_font)

    plt.grid(True)
    plt.show()

plot_for_publication(L, T)

# %%
# DEF = [0.17755559086799622, 0.17670658230781552, 0.17636779944101968, 0.17830661932627362, 0.1772066007057826] 
# # [0.09234986014900703, 0.09269516307801486, 0.09176603161271604, 0.0933278885684787, 0.09329225783428505, 0.09289330010494548, 0.0941301189067345, 0.09258023860553895, 0.09325150105333534, 0.09406236048846964] 
# KG = {key: [] for key in range(1, 5)}
# TM = {key: [] for key in range(1, 5)}

# KG[1] = [0.17456896007061004, 0.1737313836812973, 0.1738048642873764, 0.17368730008602143, 0.17297217547893523]
# TM[1]=160.6665395370003
# KG[2] = [0.1770902693271637, 0.17608982920646668, 0.17607759833335876, 0.1763090193271637, 0.17545552551746368]
# TM[2]=535.4104975919997
# KG[3] = [0.17759477496147155, 0.17663188576698302, 0.17644250790278115, 0.17729517022768657, 0.17645474175612133]
# TM[3]=979.0765865739993
# KG[4] = [0.1777270257472992, 0.1767947494983673, 0.17644617954889932, 0.17795886198679606, 0.17704986433188122]
# TM[4]=1241.6939143439997
# KG[5] = [0.17755559086799622, 0.17670658230781552, 0.17636779944101968, 0.17830661932627362, 0.1772066007057826]
# TM[5]=1305.0128386209997

# CC = [0.1488061649600665, 0.14980313898552033, 0.1735130121310552, 0.1508245036005974, 0.14943165014187496]
# # [0.0664463441464163, 0.05493319416329974, 0.07502811622051966, 0.05865990618864695, 0.060431654387050206]
# # [0.05673194486601172, 0.05756955524601268, 0.05817932698538269, 0.057842532388083595, 0.057752128588681485, 0.06096063955646028, 0.0647302408606158, 0.061339192845303606, 0.05759211477995331, 0.05836895883970318]
# L2 = [l2_loss(KG[i], DEF) for i in range(1,5)]


# TMC = [0.003198468685150147, -4.899501800537105e-05, 0.698618757724762, 0.007699823379516602, 0.1766751378774643]
# # [0.0034531354904174805, -0.00044083595275878906, 0.01699650287628174, 0.001273512840270996, 0.8648608773946762] 
# # [0.09125685157875221, 0.03193164952099323, 0.0907980686674515, 0.06359390392899514, 0.09432062767446041, 0.06197508548696837, 0.12373628765344621, 0.12266441136598591, 0.09427736463646096, 0.15580671864251297]  
# # [0.11039919331669809, 0.057824741974472994, 0.05401793040335175, 0.09412862084805965, 0.09405074618756767, 0.07518808335065841, 0.12965174205601213, 0.10921482637524606, 0.09353987120091917, 0.11232807710766787]
# print("KG-L2:", L2)
# print("KG-Time:", TM)
# cc_l2 = l2_loss(CC, DEF)

# print("CC-L2:", cc_l2, "Time=1164")
# tmc_l2= l2_loss(TMC, DEF)
# print("MC-L2:", tmc_l2, "Time=1206")

# MSE = [100*mse_loss(KG[i], DEF) for i in range(1,5)]
# print(MSE)
